# %%
import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 1000
    n = len(x)
    learning_rate = 0.001

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted)) #slope derivative 
        bd = -(2/n)*sum(y-y_predicted) #intercept derivative
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 0.0, b 0.0, cost 0 iteration 0
# m 0.0, b 0.0, cost 0.0 iteration 1
# m 0.0, b 0.0, cost 0.0 iteration 2
# m 0.0, b 0.0, cost 0.0 iteration 3
# m 0.0, b 0.0, cost 0.0 iteration 4
# m 0.0, b 0.0, cost 0.0 iteration 5
# m 0.0, b 0.0, cost 0.0 iteration 6
# m 0.0, b 0.0, cost 0.0 iteration 7
# m 0.0, b 0.0, cost 0.0 iteration 8
# m 0.0, b 0.0, cost 0.0 iteration 9
# m 0.0, b 0.0, cost 0.0 iteration 10
# m 0.0, b 0.0, cost 0.0 iteration 11
# m 0.0, b 0.0, cost 0.0 iteration 12
# m 0.0, b 0.0, cost 0.0 iteration 13
# m 0.0, b 0.0, cost 0.0 iteration 14
# m 0.0, b 0.0, cost 0.0 iteration 15
# m 0.0, b 0.0, cost 0.0 iteration 16
# m 0.0, b 0.0, cost 0.0 iteration 17
# m 0.0, b 0.0, cost 0.0 iteration 18
# m 0.0, b 0.0, cost 0.0 iteration 19
# m 0.0, b 0.0, cost 0.0 iteration 20
# m 0.0, b 0.0, cost 0.0 iteration 21
# m 0.0, b 0.0, cost 0.0 iteration 22
# m 0.0, b 0.0, cost 0.0 iteration 23
# m 0.0, b 0.0, cost 0.0 iteration 24
# m 0.0, b 0.0, cost 0.0 iteration 25
# m 0.0, b 0.0, cost 0.0 iteration 26
# m 0.0, b 0.0, cost 0.0 iteration 27
# m 0.0, b 0.0, cost 0.0 iteration 28
# m 0.0, b 0.0, cost 0.0 iteration 29
# m 0.0, b 0.0, cost 0.0 iteration 30
# m 0.0, b 0.0, cost 0.0 iteration 31
# m 0.0, b 0.0, cost 0.0 iteration 32
# m 0.0, b 0.0, cost 0.0 iteration 33
# m 0.0, b 0.0, cost 0.0 iteration 34
# m 0.0, b 0.0, cost 0.0 iteration 35
# m 0.0, b 0.0, cost 0.0 iteration 36
# m 0.0, b 0.0, cost 0.0 iteration 37
# m 0.0, b 0.0, cost 0.0 iteration 38
# m 0.0, b 0.0, cost 0.0 iteration 39
# m 0.0, b 0.0, cost 0.0 iteration 40
# m 0.0, b 0.0, cost 0.0 iteration 41
# m 0.0, b 0.0, cost 0.0 iteration 42
# m 0.0, b 0.0, cost 0.0 iteration 43
# m 0.0, b 0.0, cost 0.0 iteration 44
# m 0.0, b 0.0, cost 0.0 iteration 45
# m 0.0, b 0.0, cost 0.0 iteration 46
# m 0.0, b 0.0, cost 0.0 iteration 47
# m 0.0, b 0.0, cost 0.0 iteration 48
# m 0.0, b 0.0, cost 0.0 iteration 49
# m 0.0, b 0.0, cost 0.0 iteration 50
# m 0.0, b 0.0, cost 0.0 iteration 51
# m 0.0, b 0.0, cost 0.0 iteration 52
# m 0.0, b 0.0, cost 0.0 iteration 53
# m 0.0, b 0.0, cost 0.0 iteration 54
# m 0.0, b 0.0, cost 0.0 iteration 55
# m 0.0, b 0.0, cost 0.0 iteration 56
# m 0.0, b 0.0, cost 0.0 iteration 57
# m 0.0, b 0.0, cost 0.0 iteration 58
# m 0.0, b 0.0, cost 0.0 iteration 59
# m 0.0, b 0.0, cost 0.0 iteration 60
# m 0.0, b 0.0, cost 0.0 iteration 61
# m 0.0, b 0.0, cost 0.0 iteration 62
# m 0.0, b 0.0, cost 0.0 iteration 63
# m 0.0, b 0.0, cost 0.0 iteration 64
# m 0.0, b 0.0, cost 0.0 iteration 65
# m 0.0, b 0.0, cost 0.0 iteration 66
# m 0.0, b 0.0, cost 0.0 iteration 67
# m 0.0, b 0.0, cost 0.0 iteration 68
# m 0.0, b 0.0, cost 0.0 iteration 69
# m 0.0, b 0.0, cost 0.0 iteration 70
# m 0.0, b 0.0, cost 0.0 iteration 71
# m 0.0, b 0.0, cost 0.0 iteration 72
# m 0.0, b 0.0, cost 0.0 iteration 73
# m 0.0, b 0.0, cost 0.0 iteration 74
# m 0.0, b 0.0, cost 0.0 iteration 75
# m 0.0, b 0.0, cost 0.0 iteration 76
# m 0.0, b 0.0, cost 0.0 iteration 77
# m 0.0, b 0.0, cost 0.0 iteration 78
# m 0.0, b 0.0, cost 0.0 iteration 79
# m 0.0, b 0.0, cost 0.0 iteration 80
# m 0.0, b 0.0, cost 0.0 iteration 81
# m 0.0, b 0.0, cost 0.0 iteration 82
# m 0.0, b 0.0, cost 0.0 iteration 83
# m 0.0, b 0.0, cost 0.0 iteration 84
# m 0.0, b 0.0, cost 0.0 iteration 85
# m 0.0, b 0.0, cost 0.0 iteration 86
# m 0.0, b 0.0, cost 0.0 iteration 87
# m 0.0, b 0.0, cost 0.0 iteration 88
# m 0.0, b 0.0, cost 0.0 iteration 89
# m 0.0, b 0.0, cost 0.0 iteration 90
# m 0.0, b 0.0, cost 0.0 iteration 91
# m 0.0, b 0.0, cost 0.0 iteration 92
# m 0.0, b 0.0, cost 0.0 iteration 93
# m 0.0, b 0.0, cost 0.0 iteration 94
# m 0.0, b 0.0, cost 0.0 iteration 95
# m 0.0, b 0.0, cost 0.0 iteration 96
# m 0.0, b 0.0, cost 0.0 iteration 97
# m 0.0, b 0.0, cost 0.0 iteration 98
# m 0.0, b 0.0, cost 0.0 iteration 99
# m 0.0, b 0.0, cost 0.0 iteration 100
# m 0.0, b 0.0, cost 0.0 iteration 101
# m 0.0, b 0.0, cost 0.0 iteration 102
# m 0.0, b 0.0, cost 0.0 iteration 103
# m 0.0, b 0.0, cost 0.0 iteration 104
# m 0.0, b 0.0, cost 0.0 iteration 105
# m 0.0, b 0.0, cost 0.0 iteration 106
# m 0.0, b 0.0, cost 0.0 iteration 107
# m 0.0, b 0.0, cost 0.0 iteration 108
# m 0.0, b 0.0, cost 0.0 iteration 109
# m 0.0, b 0.0, cost 0.0 iteration 110
# m 0.0, b 0.0, cost 0.0 iteration 111
# m 0.0, b 0.0, cost 0.0 iteration 112
# m 0.0, b 0.0, cost 0.0 iteration 113
# m 0.0, b 0.0, cost 0.0 iteration 114
# m 0.0, b 0.0, cost 0.0 iteration 115
# m 0.0, b 0.0, cost 0.0 iteration 116
# m 0.0, b 0.0, cost 0.0 iteration 117
# m 0.0, b 0.0, cost 0.0 iteration 118
# m 0.0, b 0.0, cost 0.0 iteration 119
# m 0.0, b 0.0, cost 0.0 iteration 120
# m 0.0, b 0.0, cost 0.0 iteration 121
# m 0.0, b 0.0, cost 0.0 iteration 122
# m 0.0, b 0.0, cost 0.0 iteration 123
# m 0.0, b 0.0, cost 0.0 iteration 124
# m 0.0, b 0.0, cost 0.0 iteration 125
# m 0.0, b 0.0, cost 0.0 iteration 126
# m 0.0, b 0.0, cost 0.0 iteration 127
# m 0.0, b 0.0, cost 0.0 iteration 128
# m 0.0, b 0.0, cost 0.0 iteration 129
# m 0.0, b 0.0, cost 0.0 iteration 130
# m 0.0, b 0.0, cost 0.0 iteration 131
# m 0.0, b 0.0, cost 0.0 iteration 132
# m 0.0, b 0.0, cost 0.0 iteration 133
# m 0.0, b 0.0, cost 0.0 iteration 134
# m 0.0, b 0.0, cost 0.0 iteration 135
# m 0.0, b 0.0, cost 0.0 iteration 136
# m 0.0, b 0.0, cost 0.0 iteration 137
# m 0.0, b 0.0, cost 0.0 iteration 138
# m 0.0, b 0.0, cost 0.0 iteration 139
# m 0.0, b 0.0, cost 0.0 iteration 140
# m 0.0, b 0.0, cost 0.0 iteration 141
# m 0.0, b 0.0, cost 0.0 iteration 142
# m 0.0, b 0.0, cost 0.0 iteration 143
# m 0.0, b 0.0, cost 0.0 iteration 144
# m 0.0, b 0.0, cost 0.0 iteration 145
# m 0.0, b 0.0, cost 0.0 iteration 146
# m 0.0, b 0.0, cost 0.0 iteration 147
# m 0.0, b 0.0, cost 0.0 iteration 148
# m 0.0, b 0.0, cost 0.0 iteration 149
# m 0.0, b 0.0, cost 0.0 iteration 150
# m 0.0, b 0.0, cost 0.0 iteration 151
# m 0.0, b 0.0, cost 0.0 iteration 152
# m 0.0, b 0.0, cost 0.0 iteration 153
# m 0.0, b 0.0, cost 0.0 iteration 154
# m 0.0, b 0.0, cost 0.0 iteration 155
# m 0.0, b 0.0, cost 0.0 iteration 156
# m 0.0, b 0.0, cost 0.0 iteration 157
# m 0.0, b 0.0, cost 0.0 iteration 158
# m 0.0, b 0.0, cost 0.0 iteration 159
# m 0.0, b 0.0, cost 0.0 iteration 160
# m 0.0, b 0.0, cost 0.0 iteration 161
# m 0.0, b 0.0, cost 0.0 iteration 162
# m 0.0, b 0.0, cost 0.0 iteration 163
# m 0.0, b 0.0, cost 0.0 iteration 164
# m 0.0, b 0.0, cost 0.0 iteration 165
# m 0.0, b 0.0, cost 0.0 iteration 166
# m 0.0, b 0.0, cost 0.0 iteration 167
# m 0.0, b 0.0, cost 0.0 iteration 168
# m 0.0, b 0.0, cost 0.0 iteration 169
# m 0.0, b 0.0, cost 0.0 iteration 170
# m 0.0, b 0.0, cost 0.0 iteration 171
# m 0.0, b 0.0, cost 0.0 iteration 172
# m 0.0, b 0.0, cost 0.0 iteration 173
# m 0.0, b 0.0, cost 0.0 iteration 174
# m 0.0, b 0.0, cost 0.0 iteration 175
# m 0.0, b 0.0, cost 0.0 iteration 176
# m 0.0, b 0.0, cost 0.0 iteration 177
# m 0.0, b 0.0, cost 0.0 iteration 178
# m 0.0, b 0.0, cost 0.0 iteration 179
# m 0.0, b 0.0, cost 0.0 iteration 180
# m 0.0, b 0.0, cost 0.0 iteration 181
# m 0.0, b 0.0, cost 0.0 iteration 182
# m 0.0, b 0.0, cost 0.0 iteration 183
# m 0.0, b 0.0, cost 0.0 iteration 184
# m 0.0, b 0.0, cost 0.0 iteration 185
# m 0.0, b 0.0, cost 0.0 iteration 186
# m 0.0, b 0.0, cost 0.0 iteration 187
# m 0.0, b 0.0, cost 0.0 iteration 188
# m 0.0, b 0.0, cost 0.0 iteration 189
# m 0.0, b 0.0, cost 0.0 iteration 190
# m 0.0, b 0.0, cost 0.0 iteration 191
# m 0.0, b 0.0, cost 0.0 iteration 192
# m 0.0, b 0.0, cost 0.0 iteration 193
# m 0.0, b 0.0, cost 0.0 iteration 194
# m 0.0, b 0.0, cost 0.0 iteration 195
# m 0.0, b 0.0, cost 0.0 iteration 196
# m 0.0, b 0.0, cost 0.0 iteration 197
# m 0.0, b 0.0, cost 0.0 iteration 198
# m 0.0, b 0.0, cost 0.0 iteration 199
# m 0.0, b 0.0, cost 0.0 iteration 200
# m 0.0, b 0.0, cost 0.0 iteration 201
# m 0.0, b 0.0, cost 0.0 iteration 202
# m 0.0, b 0.0, cost 0.0 iteration 203
# m 0.0, b 0.0, cost 0.0 iteration 204
# m 0.0, b 0.0, cost 0.0 iteration 205
# m 0.0, b 0.0, cost 0.0 iteration 206
# m 0.0, b 0.0, cost 0.0 iteration 207
# m 0.0, b 0.0, cost 0.0 iteration 208
# m 0.0, b 0.0, cost 0.0 iteration 209
# m 0.0, b 0.0, cost 0.0 iteration 210
# m 0.0, b 0.0, cost 0.0 iteration 211
# m 0.0, b 0.0, cost 0.0 iteration 212
# m 0.0, b 0.0, cost 0.0 iteration 213
# m 0.0, b 0.0, cost 0.0 iteration 214
# m 0.0, b 0.0, cost 0.0 iteration 215
# m 0.0, b 0.0, cost 0.0 iteration 216
# m 0.0, b 0.0, cost 0.0 iteration 217
# m 0.0, b 0.0, cost 0.0 iteration 218
# m 0.0, b 0.0, cost 0.0 iteration 219
# m 0.0, b 0.0, cost 0.0 iteration 220
# m 0.0, b 0.0, cost 0.0 iteration 221
# m 0.0, b 0.0, cost 0.0 iteration 222
# m 0.0, b 0.0, cost 0.0 iteration 223
# m 0.0, b 0.0, cost 0.0 iteration 224
# m 0.0, b 0.0, cost 0.0 iteration 225
# m 0.0, b 0.0, cost 0.0 iteration 226
# m 0.0, b 0.0, cost 0.0 iteration 227
# m 0.0, b 0.0, cost 0.0 iteration 228
# m 0.0, b 0.0, cost 0.0 iteration 229
# m 0.0, b 0.0, cost 0.0 iteration 230
# m 0.0, b 0.0, cost 0.0 iteration 231
# m 0.0, b 0.0, cost 0.0 iteration 232
# m 0.0, b 0.0, cost 0.0 iteration 233
# m 0.0, b 0.0, cost 0.0 iteration 234
# m 0.0, b 0.0, cost 0.0 iteration 235
# m 0.0, b 0.0, cost 0.0 iteration 236
# m 0.0, b 0.0, cost 0.0 iteration 237
# m 0.0, b 0.0, cost 0.0 iteration 238
# m 0.0, b 0.0, cost 0.0 iteration 239
# m 0.0, b 0.0, cost 0.0 iteration 240
# m 0.0, b 0.0, cost 0.0 iteration 241
# m 0.0, b 0.0, cost 0.0 iteration 242
# m 0.0, b 0.0, cost 0.0 iteration 243
# m 0.0, b 0.0, cost 0.0 iteration 244
# m 0.0, b 0.0, cost 0.0 iteration 245
# m 0.0, b 0.0, cost 0.0 iteration 246
# m 0.0, b 0.0, cost 0.0 iteration 247
# m 0.0, b 0.0, cost 0.0 iteration 248
# m 0.0, b 0.0, cost 0.0 iteration 249
# m 0.0, b 0.0, cost 0.0 iteration 250
# m 0.0, b 0.0, cost 0.0 iteration 251
# m 0.0, b 0.0, cost 0.0 iteration 252
# m 0.0, b 0.0, cost 0.0 iteration 253
# m 0.0, b 0.0, cost 0.0 iteration 254
# m 0.0, b 0.0, cost 0.0 iteration 255
# m 0.0, b 0.0, cost 0.0 iteration 256
# m 0.0, b 0.0, cost 0.0 iteration 257
# m 0.0, b 0.0, cost 0.0 iteration 258
# m 0.0, b 0.0, cost 0.0 iteration 259
# m 0.0, b 0.0, cost 0.0 iteration 260
# m 0.0, b 0.0, cost 0.0 iteration 261
# m 0.0, b 0.0, cost 0.0 iteration 262
# m 0.0, b 0.0, cost 0.0 iteration 263
# m 0.0, b 0.0, cost 0.0 iteration 264
# m 0.0, b 0.0, cost 0.0 iteration 265
# m 0.0, b 0.0, cost 0.0 iteration 266
# m 0.0, b 0.0, cost 0.0 iteration 267
# m 0.0, b 0.0, cost 0.0 iteration 268
# m 0.0, b 0.0, cost 0.0 iteration 269
# m 0.0, b 0.0, cost 0.0 iteration 270
# m 0.0, b 0.0, cost 0.0 iteration 271
# m 0.0, b 0.0, cost 0.0 iteration 272
# m 0.0, b 0.0, cost 0.0 iteration 273
# m 0.0, b 0.0, cost 0.0 iteration 274
# m 0.0, b 0.0, cost 0.0 iteration 275
# m 0.0, b 0.0, cost 0.0 iteration 276
# m 0.0, b 0.0, cost 0.0 iteration 277
# m 0.0, b 0.0, cost 0.0 iteration 278
# m 0.0, b 0.0, cost 0.0 iteration 279
# m 0.0, b 0.0, cost 0.0 iteration 280
# m 0.0, b 0.0, cost 0.0 iteration 281
# m 0.0, b 0.0, cost 0.0 iteration 282
# m 0.0, b 0.0, cost 0.0 iteration 283
# m 0.0, b 0.0, cost 0.0 iteration 284
# m 0.0, b 0.0, cost 0.0 iteration 285
# m 0.0, b 0.0, cost 0.0 iteration 286
# m 0.0, b 0.0, cost 0.0 iteration 287
# m 0.0, b 0.0, cost 0.0 iteration 288
# m 0.0, b 0.0, cost 0.0 iteration 289
# m 0.0, b 0.0, cost 0.0 iteration 290
# m 0.0, b 0.0, cost 0.0 iteration 291
# m 0.0, b 0.0, cost 0.0 iteration 292
# m 0.0, b 0.0, cost 0.0 iteration 293
# m 0.0, b 0.0, cost 0.0 iteration 294
# m 0.0, b 0.0, cost 0.0 iteration 295
# m 0.0, b 0.0, cost 0.0 iteration 296
# m 0.0, b 0.0, cost 0.0 iteration 297
# m 0.0, b 0.0, cost 0.0 iteration 298
# m 0.0, b 0.0, cost 0.0 iteration 299
# m 0.0, b 0.0, cost 0.0 iteration 300
# m 0.0, b 0.0, cost 0.0 iteration 301
# m 0.0, b 0.0, cost 0.0 iteration 302
# m 0.0, b 0.0, cost 0.0 iteration 303
# m 0.0, b 0.0, cost 0.0 iteration 304
# m 0.0, b 0.0, cost 0.0 iteration 305
# m 0.0, b 0.0, cost 0.0 iteration 306
# m 0.0, b 0.0, cost 0.0 iteration 307
# m 0.0, b 0.0, cost 0.0 iteration 308
# m 0.0, b 0.0, cost 0.0 iteration 309
# m 0.0, b 0.0, cost 0.0 iteration 310
# m 0.0, b 0.0, cost 0.0 iteration 311
# m 0.0, b 0.0, cost 0.0 iteration 312
# m 0.0, b 0.0, cost 0.0 iteration 313
# m 0.0, b 0.0, cost 0.0 iteration 314
# m 0.0, b 0.0, cost 0.0 iteration 315
# m 0.0, b 0.0, cost 0.0 iteration 316
# m 0.0, b 0.0, cost 0.0 iteration 317
# m 0.0, b 0.0, cost 0.0 iteration 318
# m 0.0, b 0.0, cost 0.0 iteration 319
# m 0.0, b 0.0, cost 0.0 iteration 320
# m 0.0, b 0.0, cost 0.0 iteration 321
# m 0.0, b 0.0, cost 0.0 iteration 322
# m 0.0, b 0.0, cost 0.0 iteration 323
# m 0.0, b 0.0, cost 0.0 iteration 324
# m 0.0, b 0.0, cost 0.0 iteration 325
# m 0.0, b 0.0, cost 0.0 iteration 326
# m 0.0, b 0.0, cost 0.0 iteration 327
# m 0.0, b 0.0, cost 0.0 iteration 328
# m 0.0, b 0.0, cost 0.0 iteration 329
# m 0.0, b 0.0, cost 0.0 iteration 330
# m 0.0, b 0.0, cost 0.0 iteration 331
# m 0.0, b 0.0, cost 0.0 iteration 332
# m 0.0, b 0.0, cost 0.0 iteration 333
# m 0.0, b 0.0, cost 0.0 iteration 334
# m 0.0, b 0.0, cost 0.0 iteration 335
# m 0.0, b 0.0, cost 0.0 iteration 336
# m 0.0, b 0.0, cost 0.0 iteration 337
# m 0.0, b 0.0, cost 0.0 iteration 338
# m 0.0, b 0.0, cost 0.0 iteration 339
# m 0.0, b 0.0, cost 0.0 iteration 340
# m 0.0, b 0.0, cost 0.0 iteration 341
# m 0.0, b 0.0, cost 0.0 iteration 342
# m 0.0, b 0.0, cost 0.0 iteration 343
# m 0.0, b 0.0, cost 0.0 iteration 344
# m 0.0, b 0.0, cost 0.0 iteration 345
# m 0.0, b 0.0, cost 0.0 iteration 346
# m 0.0, b 0.0, cost 0.0 iteration 347
# m 0.0, b 0.0, cost 0.0 iteration 348
# m 0.0, b 0.0, cost 0.0 iteration 349
# m 0.0, b 0.0, cost 0.0 iteration 350
# m 0.0, b 0.0, cost 0.0 iteration 351
# m 0.0, b 0.0, cost 0.0 iteration 352
# m 0.0, b 0.0, cost 0.0 iteration 353
# m 0.0, b 0.0, cost 0.0 iteration 354
# m 0.0, b 0.0, cost 0.0 iteration 355
# m 0.0, b 0.0, cost 0.0 iteration 356
# m 0.0, b 0.0, cost 0.0 iteration 357
# m 0.0, b 0.0, cost 0.0 iteration 358
# m 0.0, b 0.0, cost 0.0 iteration 359
# m 0.0, b 0.0, cost 0.0 iteration 360
# m 0.0, b 0.0, cost 0.0 iteration 361
# m 0.0, b 0.0, cost 0.0 iteration 362
# m 0.0, b 0.0, cost 0.0 iteration 363
# m 0.0, b 0.0, cost 0.0 iteration 364
# m 0.0, b 0.0, cost 0.0 iteration 365
# m 0.0, b 0.0, cost 0.0 iteration 366
# m 0.0, b 0.0, cost 0.0 iteration 367
# m 0.0, b 0.0, cost 0.0 iteration 368
# m 0.0, b 0.0, cost 0.0 iteration 369
# m 0.0, b 0.0, cost 0.0 iteration 370
# m 0.0, b 0.0, cost 0.0 iteration 371
# m 0.0, b 0.0, cost 0.0 iteration 372
# m 0.0, b 0.0, cost 0.0 iteration 373
# m 0.0, b 0.0, cost 0.0 iteration 374
# m 0.0, b 0.0, cost 0.0 iteration 375
# m 0.0, b 0.0, cost 0.0 iteration 376
# m 0.0, b 0.0, cost 0.0 iteration 377
# m 0.0, b 0.0, cost 0.0 iteration 378
# m 0.0, b 0.0, cost 0.0 iteration 379
# m 0.0, b 0.0, cost 0.0 iteration 380
# m 0.0, b 0.0, cost 0.0 iteration 381
# m 0.0, b 0.0, cost 0.0 iteration 382
# m 0.0, b 0.0, cost 0.0 iteration 383
# m 0.0, b 0.0, cost 0.0 iteration 384
# m 0.0, b 0.0, cost 0.0 iteration 385
# m 0.0, b 0.0, cost 0.0 iteration 386
# m 0.0, b 0.0, cost 0.0 iteration 387
# m 0.0, b 0.0, cost 0.0 iteration 388
# m 0.0, b 0.0, cost 0.0 iteration 389
# m 0.0, b 0.0, cost 0.0 iteration 390
# m 0.0, b 0.0, cost 0.0 iteration 391
# m 0.0, b 0.0, cost 0.0 iteration 392
# m 0.0, b 0.0, cost 0.0 iteration 393
# m 0.0, b 0.0, cost 0.0 iteration 394
# m 0.0, b 0.0, cost 0.0 iteration 395
# m 0.0, b 0.0, cost 0.0 iteration 396
# m 0.0, b 0.0, cost 0.0 iteration 397
# m 0.0, b 0.0, cost 0.0 iteration 398
# m 0.0, b 0.0, cost 0.0 iteration 399
# m 0.0, b 0.0, cost 0.0 iteration 400
# m 0.0, b 0.0, cost 0.0 iteration 401
# m 0.0, b 0.0, cost 0.0 iteration 402
# m 0.0, b 0.0, cost 0.0 iteration 403
# m 0.0, b 0.0, cost 0.0 iteration 404
# m 0.0, b 0.0, cost 0.0 iteration 405
# m 0.0, b 0.0, cost 0.0 iteration 406
# m 0.0, b 0.0, cost 0.0 iteration 407
# m 0.0, b 0.0, cost 0.0 iteration 408
# m 0.0, b 0.0, cost 0.0 iteration 409
# m 0.0, b 0.0, cost 0.0 iteration 410
# m 0.0, b 0.0, cost 0.0 iteration 411
# m 0.0, b 0.0, cost 0.0 iteration 412
# m 0.0, b 0.0, cost 0.0 iteration 413
# m 0.0, b 0.0, cost 0.0 iteration 414
# m 0.0, b 0.0, cost 0.0 iteration 415
# m 0.0, b 0.0, cost 0.0 iteration 416
# m 0.0, b 0.0, cost 0.0 iteration 417
# m 0.0, b 0.0, cost 0.0 iteration 418
# m 0.0, b 0.0, cost 0.0 iteration 419
# m 0.0, b 0.0, cost 0.0 iteration 420
# m 0.0, b 0.0, cost 0.0 iteration 421
# m 0.0, b 0.0, cost 0.0 iteration 422
# m 0.0, b 0.0, cost 0.0 iteration 423
# m 0.0, b 0.0, cost 0.0 iteration 424
# m 0.0, b 0.0, cost 0.0 iteration 425
# m 0.0, b 0.0, cost 0.0 iteration 426
# m 0.0, b 0.0, cost 0.0 iteration 427
# m 0.0, b 0.0, cost 0.0 iteration 428
# m 0.0, b 0.0, cost 0.0 iteration 429
# m 0.0, b 0.0, cost 0.0 iteration 430
# m 0.0, b 0.0, cost 0.0 iteration 431
# m 0.0, b 0.0, cost 0.0 iteration 432
# m 0.0, b 0.0, cost 0.0 iteration 433
# m 0.0, b 0.0, cost 0.0 iteration 434
# m 0.0, b 0.0, cost 0.0 iteration 435
# m 0.0, b 0.0, cost 0.0 iteration 436
# m 0.0, b 0.0, cost 0.0 iteration 437
# m 0.0, b 0.0, cost 0.0 iteration 438
# m 0.0, b 0.0, cost 0.0 iteration 439
# m 0.0, b 0.0, cost 0.0 iteration 440
# m 0.0, b 0.0, cost 0.0 iteration 441
# m 0.0, b 0.0, cost 0.0 iteration 442
# m 0.0, b 0.0, cost 0.0 iteration 443
# m 0.0, b 0.0, cost 0.0 iteration 444
# m 0.0, b 0.0, cost 0.0 iteration 445
# m 0.0, b 0.0, cost 0.0 iteration 446
# m 0.0, b 0.0, cost 0.0 iteration 447
# m 0.0, b 0.0, cost 0.0 iteration 448
# m 0.0, b 0.0, cost 0.0 iteration 449
# m 0.0, b 0.0, cost 0.0 iteration 450
# m 0.0, b 0.0, cost 0.0 iteration 451
# m 0.0, b 0.0, cost 0.0 iteration 452
# m 0.0, b 0.0, cost 0.0 iteration 453
# m 0.0, b 0.0, cost 0.0 iteration 454
# m 0.0, b 0.0, cost 0.0 iteration 455
# m 0.0, b 0.0, cost 0.0 iteration 456
# m 0.0, b 0.0, cost 0.0 iteration 457
# m 0.0, b 0.0, cost 0.0 iteration 458
# m 0.0, b 0.0, cost 0.0 iteration 459
# m 0.0, b 0.0, cost 0.0 iteration 460
# m 0.0, b 0.0, cost 0.0 iteration 461
# m 0.0, b 0.0, cost 0.0 iteration 462
# m 0.0, b 0.0, cost 0.0 iteration 463
# m 0.0, b 0.0, cost 0.0 iteration 464
# m 0.0, b 0.0, cost 0.0 iteration 465
# m 0.0, b 0.0, cost 0.0 iteration 466
# m 0.0, b 0.0, cost 0.0 iteration 467
# m 0.0, b 0.0, cost 0.0 iteration 468
# m 0.0, b 0.0, cost 0.0 iteration 469
# m 0.0, b 0.0, cost 0.0 iteration 470
# m 0.0, b 0.0, cost 0.0 iteration 471
# m 0.0, b 0.0, cost 0.0 iteration 472
# m 0.0, b 0.0, cost 0.0 iteration 473
# m 0.0, b 0.0, cost 0.0 iteration 474
# m 0.0, b 0.0, cost 0.0 iteration 475
# m 0.0, b 0.0, cost 0.0 iteration 476
# m 0.0, b 0.0, cost 0.0 iteration 477
# m 0.0, b 0.0, cost 0.0 iteration 478
# m 0.0, b 0.0, cost 0.0 iteration 479
# m 0.0, b 0.0, cost 0.0 iteration 480
# m 0.0, b 0.0, cost 0.0 iteration 481
# m 0.0, b 0.0, cost 0.0 iteration 482
# m 0.0, b 0.0, cost 0.0 iteration 483
# m 0.0, b 0.0, cost 0.0 iteration 484
# m 0.0, b 0.0, cost 0.0 iteration 485
# m 0.0, b 0.0, cost 0.0 iteration 486
# m 0.0, b 0.0, cost 0.0 iteration 487
# m 0.0, b 0.0, cost 0.0 iteration 488
# m 0.0, b 0.0, cost 0.0 iteration 489
# m 0.0, b 0.0, cost 0.0 iteration 490
# m 0.0, b 0.0, cost 0.0 iteration 491
# m 0.0, b 0.0, cost 0.0 iteration 492
# m 0.0, b 0.0, cost 0.0 iteration 493
# m 0.0, b 0.0, cost 0.0 iteration 494
# m 0.0, b 0.0, cost 0.0 iteration 495
# m 0.0, b 0.0, cost 0.0 iteration 496
# m 0.0, b 0.0, cost 0.0 iteration 497
# m 0.0, b 0.0, cost 0.0 iteration 498
# m 0.0, b 0.0, cost 0.0 iteration 499
# m 0.0, b 0.0, cost 0.0 iteration 500
# m 0.0, b 0.0, cost 0.0 iteration 501
# m 0.0, b 0.0, cost 0.0 iteration 502
# m 0.0, b 0.0, cost 0.0 iteration 503
# m 0.0, b 0.0, cost 0.0 iteration 504
# m 0.0, b 0.0, cost 0.0 iteration 505
# m 0.0, b 0.0, cost 0.0 iteration 506
# m 0.0, b 0.0, cost 0.0 iteration 507
# m 0.0, b 0.0, cost 0.0 iteration 508
# m 0.0, b 0.0, cost 0.0 iteration 509
# m 0.0, b 0.0, cost 0.0 iteration 510
# m 0.0, b 0.0, cost 0.0 iteration 511
# m 0.0, b 0.0, cost 0.0 iteration 512
# m 0.0, b 0.0, cost 0.0 iteration 513
# m 0.0, b 0.0, cost 0.0 iteration 514
# m 0.0, b 0.0, cost 0.0 iteration 515
# m 0.0, b 0.0, cost 0.0 iteration 516
# m 0.0, b 0.0, cost 0.0 iteration 517
# m 0.0, b 0.0, cost 0.0 iteration 518
# m 0.0, b 0.0, cost 0.0 iteration 519
# m 0.0, b 0.0, cost 0.0 iteration 520
# m 0.0, b 0.0, cost 0.0 iteration 521
# m 0.0, b 0.0, cost 0.0 iteration 522
# m 0.0, b 0.0, cost 0.0 iteration 523
# m 0.0, b 0.0, cost 0.0 iteration 524
# m 0.0, b 0.0, cost 0.0 iteration 525
# m 0.0, b 0.0, cost 0.0 iteration 526
# m 0.0, b 0.0, cost 0.0 iteration 527
# m 0.0, b 0.0, cost 0.0 iteration 528
# m 0.0, b 0.0, cost 0.0 iteration 529
# m 0.0, b 0.0, cost 0.0 iteration 530
# m 0.0, b 0.0, cost 0.0 iteration 531
# m 0.0, b 0.0, cost 0.0 iteration 532
# m 0.0, b 0.0, cost 0.0 iteration 533
# m 0.0, b 0.0, cost 0.0 iteration 534
# m 0.0, b 0.0, cost 0.0 iteration 535
# m 0.0, b 0.0, cost 0.0 iteration 536
# m 0.0, b 0.0, cost 0.0 iteration 537
# m 0.0, b 0.0, cost 0.0 iteration 538
# m 0.0, b 0.0, cost 0.0 iteration 539
# m 0.0, b 0.0, cost 0.0 iteration 540
# m 0.0, b 0.0, cost 0.0 iteration 541
# m 0.0, b 0.0, cost 0.0 iteration 542
# m 0.0, b 0.0, cost 0.0 iteration 543
# m 0.0, b 0.0, cost 0.0 iteration 544
# m 0.0, b 0.0, cost 0.0 iteration 545
# m 0.0, b 0.0, cost 0.0 iteration 546
# m 0.0, b 0.0, cost 0.0 iteration 547
# m 0.0, b 0.0, cost 0.0 iteration 548
# m 0.0, b 0.0, cost 0.0 iteration 549
# m 0.0, b 0.0, cost 0.0 iteration 550
# m 0.0, b 0.0, cost 0.0 iteration 551
# m 0.0, b 0.0, cost 0.0 iteration 552
# m 0.0, b 0.0, cost 0.0 iteration 553
# m 0.0, b 0.0, cost 0.0 iteration 554
# m 0.0, b 0.0, cost 0.0 iteration 555
# m 0.0, b 0.0, cost 0.0 iteration 556
# m 0.0, b 0.0, cost 0.0 iteration 557
# m 0.0, b 0.0, cost 0.0 iteration 558
# m 0.0, b 0.0, cost 0.0 iteration 559
# m 0.0, b 0.0, cost 0.0 iteration 560
# m 0.0, b 0.0, cost 0.0 iteration 561
# m 0.0, b 0.0, cost 0.0 iteration 562
# m 0.0, b 0.0, cost 0.0 iteration 563
# m 0.0, b 0.0, cost 0.0 iteration 564
# m 0.0, b 0.0, cost 0.0 iteration 565
# m 0.0, b 0.0, cost 0.0 iteration 566
# m 0.0, b 0.0, cost 0.0 iteration 567
# m 0.0, b 0.0, cost 0.0 iteration 568
# m 0.0, b 0.0, cost 0.0 iteration 569
# m 0.0, b 0.0, cost 0.0 iteration 570
# m 0.0, b 0.0, cost 0.0 iteration 571
# m 0.0, b 0.0, cost 0.0 iteration 572
# m 0.0, b 0.0, cost 0.0 iteration 573
# m 0.0, b 0.0, cost 0.0 iteration 574
# m 0.0, b 0.0, cost 0.0 iteration 575
# m 0.0, b 0.0, cost 0.0 iteration 576
# m 0.0, b 0.0, cost 0.0 iteration 577
# m 0.0, b 0.0, cost 0.0 iteration 578
# m 0.0, b 0.0, cost 0.0 iteration 579
# m 0.0, b 0.0, cost 0.0 iteration 580
# m 0.0, b 0.0, cost 0.0 iteration 581
# m 0.0, b 0.0, cost 0.0 iteration 582
# m 0.0, b 0.0, cost 0.0 iteration 583
# m 0.0, b 0.0, cost 0.0 iteration 584
# m 0.0, b 0.0, cost 0.0 iteration 585
# m 0.0, b 0.0, cost 0.0 iteration 586
# m 0.0, b 0.0, cost 0.0 iteration 587
# m 0.0, b 0.0, cost 0.0 iteration 588
# m 0.0, b 0.0, cost 0.0 iteration 589
# m 0.0, b 0.0, cost 0.0 iteration 590
# m 0.0, b 0.0, cost 0.0 iteration 591
# m 0.0, b 0.0, cost 0.0 iteration 592
# m 0.0, b 0.0, cost 0.0 iteration 593
# m 0.0, b 0.0, cost 0.0 iteration 594
# m 0.0, b 0.0, cost 0.0 iteration 595
# m 0.0, b 0.0, cost 0.0 iteration 596
# m 0.0, b 0.0, cost 0.0 iteration 597
# m 0.0, b 0.0, cost 0.0 iteration 598
# m 0.0, b 0.0, cost 0.0 iteration 599
# m 0.0, b 0.0, cost 0.0 iteration 600
# m 0.0, b 0.0, cost 0.0 iteration 601
# m 0.0, b 0.0, cost 0.0 iteration 602
# m 0.0, b 0.0, cost 0.0 iteration 603
# m 0.0, b 0.0, cost 0.0 iteration 604
# m 0.0, b 0.0, cost 0.0 iteration 605
# m 0.0, b 0.0, cost 0.0 iteration 606
# m 0.0, b 0.0, cost 0.0 iteration 607
# m 0.0, b 0.0, cost 0.0 iteration 608
# m 0.0, b 0.0, cost 0.0 iteration 609
# m 0.0, b 0.0, cost 0.0 iteration 610
# m 0.0, b 0.0, cost 0.0 iteration 611
# m 0.0, b 0.0, cost 0.0 iteration 612
# m 0.0, b 0.0, cost 0.0 iteration 613
# m 0.0, b 0.0, cost 0.0 iteration 614
# m 0.0, b 0.0, cost 0.0 iteration 615
# m 0.0, b 0.0, cost 0.0 iteration 616
# m 0.0, b 0.0, cost 0.0 iteration 617
# m 0.0, b 0.0, cost 0.0 iteration 618
# m 0.0, b 0.0, cost 0.0 iteration 619
# m 0.0, b 0.0, cost 0.0 iteration 620
# m 0.0, b 0.0, cost 0.0 iteration 621
# m 0.0, b 0.0, cost 0.0 iteration 622
# m 0.0, b 0.0, cost 0.0 iteration 623
# m 0.0, b 0.0, cost 0.0 iteration 624
# m 0.0, b 0.0, cost 0.0 iteration 625
# m 0.0, b 0.0, cost 0.0 iteration 626
# m 0.0, b 0.0, cost 0.0 iteration 627
# m 0.0, b 0.0, cost 0.0 iteration 628
# m 0.0, b 0.0, cost 0.0 iteration 629
# m 0.0, b 0.0, cost 0.0 iteration 630
# m 0.0, b 0.0, cost 0.0 iteration 631
# m 0.0, b 0.0, cost 0.0 iteration 632
# m 0.0, b 0.0, cost 0.0 iteration 633
# m 0.0, b 0.0, cost 0.0 iteration 634
# m 0.0, b 0.0, cost 0.0 iteration 635
# m 0.0, b 0.0, cost 0.0 iteration 636
# m 0.0, b 0.0, cost 0.0 iteration 637
# m 0.0, b 0.0, cost 0.0 iteration 638
# m 0.0, b 0.0, cost 0.0 iteration 639
# m 0.0, b 0.0, cost 0.0 iteration 640
# m 0.0, b 0.0, cost 0.0 iteration 641
# m 0.0, b 0.0, cost 0.0 iteration 642
# m 0.0, b 0.0, cost 0.0 iteration 643
# m 0.0, b 0.0, cost 0.0 iteration 644
# m 0.0, b 0.0, cost 0.0 iteration 645
# m 0.0, b 0.0, cost 0.0 iteration 646
# m 0.0, b 0.0, cost 0.0 iteration 647
# m 0.0, b 0.0, cost 0.0 iteration 648
# m 0.0, b 0.0, cost 0.0 iteration 649
# m 0.0, b 0.0, cost 0.0 iteration 650
# m 0.0, b 0.0, cost 0.0 iteration 651
# m 0.0, b 0.0, cost 0.0 iteration 652
# m 0.0, b 0.0, cost 0.0 iteration 653
# m 0.0, b 0.0, cost 0.0 iteration 654
# m 0.0, b 0.0, cost 0.0 iteration 655
# m 0.0, b 0.0, cost 0.0 iteration 656
# m 0.0, b 0.0, cost 0.0 iteration 657
# m 0.0, b 0.0, cost 0.0 iteration 658
# m 0.0, b 0.0, cost 0.0 iteration 659
# m 0.0, b 0.0, cost 0.0 iteration 660
# m 0.0, b 0.0, cost 0.0 iteration 661
# m 0.0, b 0.0, cost 0.0 iteration 662
# m 0.0, b 0.0, cost 0.0 iteration 663
# m 0.0, b 0.0, cost 0.0 iteration 664
# m 0.0, b 0.0, cost 0.0 iteration 665
# m 0.0, b 0.0, cost 0.0 iteration 666
# m 0.0, b 0.0, cost 0.0 iteration 667
# m 0.0, b 0.0, cost 0.0 iteration 668
# m 0.0, b 0.0, cost 0.0 iteration 669
# m 0.0, b 0.0, cost 0.0 iteration 670
# m 0.0, b 0.0, cost 0.0 iteration 671
# m 0.0, b 0.0, cost 0.0 iteration 672
# m 0.0, b 0.0, cost 0.0 iteration 673
# m 0.0, b 0.0, cost 0.0 iteration 674
# m 0.0, b 0.0, cost 0.0 iteration 675
# m 0.0, b 0.0, cost 0.0 iteration 676
# m 0.0, b 0.0, cost 0.0 iteration 677
# m 0.0, b 0.0, cost 0.0 iteration 678
# m 0.0, b 0.0, cost 0.0 iteration 679
# m 0.0, b 0.0, cost 0.0 iteration 680
# m 0.0, b 0.0, cost 0.0 iteration 681
# m 0.0, b 0.0, cost 0.0 iteration 682
# m 0.0, b 0.0, cost 0.0 iteration 683
# m 0.0, b 0.0, cost 0.0 iteration 684
# m 0.0, b 0.0, cost 0.0 iteration 685
# m 0.0, b 0.0, cost 0.0 iteration 686
# m 0.0, b 0.0, cost 0.0 iteration 687
# m 0.0, b 0.0, cost 0.0 iteration 688
# m 0.0, b 0.0, cost 0.0 iteration 689
# m 0.0, b 0.0, cost 0.0 iteration 690
# m 0.0, b 0.0, cost 0.0 iteration 691
# m 0.0, b 0.0, cost 0.0 iteration 692
# m 0.0, b 0.0, cost 0.0 iteration 693
# m 0.0, b 0.0, cost 0.0 iteration 694
# m 0.0, b 0.0, cost 0.0 iteration 695
# m 0.0, b 0.0, cost 0.0 iteration 696
# m 0.0, b 0.0, cost 0.0 iteration 697
# m 0.0, b 0.0, cost 0.0 iteration 698
# m 0.0, b 0.0, cost 0.0 iteration 699
# m 0.0, b 0.0, cost 0.0 iteration 700
# m 0.0, b 0.0, cost 0.0 iteration 701
# m 0.0, b 0.0, cost 0.0 iteration 702
# m 0.0, b 0.0, cost 0.0 iteration 703
# m 0.0, b 0.0, cost 0.0 iteration 704
# m 0.0, b 0.0, cost 0.0 iteration 705
# m 0.0, b 0.0, cost 0.0 iteration 706
# m 0.0, b 0.0, cost 0.0 iteration 707
# m 0.0, b 0.0, cost 0.0 iteration 708
# m 0.0, b 0.0, cost 0.0 iteration 709
# m 0.0, b 0.0, cost 0.0 iteration 710
# m 0.0, b 0.0, cost 0.0 iteration 711
# m 0.0, b 0.0, cost 0.0 iteration 712
# m 0.0, b 0.0, cost 0.0 iteration 713
# m 0.0, b 0.0, cost 0.0 iteration 714
# m 0.0, b 0.0, cost 0.0 iteration 715
# m 0.0, b 0.0, cost 0.0 iteration 716
# m 0.0, b 0.0, cost 0.0 iteration 717
# m 0.0, b 0.0, cost 0.0 iteration 718
# m 0.0, b 0.0, cost 0.0 iteration 719
# m 0.0, b 0.0, cost 0.0 iteration 720
# m 0.0, b 0.0, cost 0.0 iteration 721
# m 0.0, b 0.0, cost 0.0 iteration 722
# m 0.0, b 0.0, cost 0.0 iteration 723
# m 0.0, b 0.0, cost 0.0 iteration 724
# m 0.0, b 0.0, cost 0.0 iteration 725
# m 0.0, b 0.0, cost 0.0 iteration 726
# m 0.0, b 0.0, cost 0.0 iteration 727
# m 0.0, b 0.0, cost 0.0 iteration 728
# m 0.0, b 0.0, cost 0.0 iteration 729
# m 0.0, b 0.0, cost 0.0 iteration 730
# m 0.0, b 0.0, cost 0.0 iteration 731
# m 0.0, b 0.0, cost 0.0 iteration 732
# m 0.0, b 0.0, cost 0.0 iteration 733
# m 0.0, b 0.0, cost 0.0 iteration 734
# m 0.0, b 0.0, cost 0.0 iteration 735
# m 0.0, b 0.0, cost 0.0 iteration 736
# m 0.0, b 0.0, cost 0.0 iteration 737
# m 0.0, b 0.0, cost 0.0 iteration 738
# m 0.0, b 0.0, cost 0.0 iteration 739
# m 0.0, b 0.0, cost 0.0 iteration 740
# m 0.0, b 0.0, cost 0.0 iteration 741
# m 0.0, b 0.0, cost 0.0 iteration 742
# m 0.0, b 0.0, cost 0.0 iteration 743
# m 0.0, b 0.0, cost 0.0 iteration 744
# m 0.0, b 0.0, cost 0.0 iteration 745
# m 0.0, b 0.0, cost 0.0 iteration 746
# m 0.0, b 0.0, cost 0.0 iteration 747
# m 0.0, b 0.0, cost 0.0 iteration 748
# m 0.0, b 0.0, cost 0.0 iteration 749
# m 0.0, b 0.0, cost 0.0 iteration 750
# m 0.0, b 0.0, cost 0.0 iteration 751
# m 0.0, b 0.0, cost 0.0 iteration 752
# m 0.0, b 0.0, cost 0.0 iteration 753
# m 0.0, b 0.0, cost 0.0 iteration 754
# m 0.0, b 0.0, cost 0.0 iteration 755
# m 0.0, b 0.0, cost 0.0 iteration 756
# m 0.0, b 0.0, cost 0.0 iteration 757
# m 0.0, b 0.0, cost 0.0 iteration 758
# m 0.0, b 0.0, cost 0.0 iteration 759
# m 0.0, b 0.0, cost 0.0 iteration 760
# m 0.0, b 0.0, cost 0.0 iteration 761
# m 0.0, b 0.0, cost 0.0 iteration 762
# m 0.0, b 0.0, cost 0.0 iteration 763
# m 0.0, b 0.0, cost 0.0 iteration 764
# m 0.0, b 0.0, cost 0.0 iteration 765
# m 0.0, b 0.0, cost 0.0 iteration 766
# m 0.0, b 0.0, cost 0.0 iteration 767
# m 0.0, b 0.0, cost 0.0 iteration 768
# m 0.0, b 0.0, cost 0.0 iteration 769
# m 0.0, b 0.0, cost 0.0 iteration 770
# m 0.0, b 0.0, cost 0.0 iteration 771
# m 0.0, b 0.0, cost 0.0 iteration 772
# m 0.0, b 0.0, cost 0.0 iteration 773
# m 0.0, b 0.0, cost 0.0 iteration 774
# m 0.0, b 0.0, cost 0.0 iteration 775
# m 0.0, b 0.0, cost 0.0 iteration 776
# m 0.0, b 0.0, cost 0.0 iteration 777
# m 0.0, b 0.0, cost 0.0 iteration 778
# m 0.0, b 0.0, cost 0.0 iteration 779
# m 0.0, b 0.0, cost 0.0 iteration 780
# m 0.0, b 0.0, cost 0.0 iteration 781
# m 0.0, b 0.0, cost 0.0 iteration 782
# m 0.0, b 0.0, cost 0.0 iteration 783
# m 0.0, b 0.0, cost 0.0 iteration 784
# m 0.0, b 0.0, cost 0.0 iteration 785
# m 0.0, b 0.0, cost 0.0 iteration 786
# m 0.0, b 0.0, cost 0.0 iteration 787
# m 0.0, b 0.0, cost 0.0 iteration 788
# m 0.0, b 0.0, cost 0.0 iteration 789
# m 0.0, b 0.0, cost 0.0 iteration 790
# m 0.0, b 0.0, cost 0.0 iteration 791
# m 0.0, b 0.0, cost 0.0 iteration 792
# m 0.0, b 0.0, cost 0.0 iteration 793
# m 0.0, b 0.0, cost 0.0 iteration 794
# m 0.0, b 0.0, cost 0.0 iteration 795
# m 0.0, b 0.0, cost 0.0 iteration 796
# m 0.0, b 0.0, cost 0.0 iteration 797
# m 0.0, b 0.0, cost 0.0 iteration 798
# m 0.0, b 0.0, cost 0.0 iteration 799
# m 0.0, b 0.0, cost 0.0 iteration 800
# m 0.0, b 0.0, cost 0.0 iteration 801
# m 0.0, b 0.0, cost 0.0 iteration 802
# m 0.0, b 0.0, cost 0.0 iteration 803
# m 0.0, b 0.0, cost 0.0 iteration 804
# m 0.0, b 0.0, cost 0.0 iteration 805
# m 0.0, b 0.0, cost 0.0 iteration 806
# m 0.0, b 0.0, cost 0.0 iteration 807
# m 0.0, b 0.0, cost 0.0 iteration 808
# m 0.0, b 0.0, cost 0.0 iteration 809
# m 0.0, b 0.0, cost 0.0 iteration 810
# m 0.0, b 0.0, cost 0.0 iteration 811
# m 0.0, b 0.0, cost 0.0 iteration 812
# m 0.0, b 0.0, cost 0.0 iteration 813
# m 0.0, b 0.0, cost 0.0 iteration 814
# m 0.0, b 0.0, cost 0.0 iteration 815
# m 0.0, b 0.0, cost 0.0 iteration 816
# m 0.0, b 0.0, cost 0.0 iteration 817
# m 0.0, b 0.0, cost 0.0 iteration 818
# m 0.0, b 0.0, cost 0.0 iteration 819
# m 0.0, b 0.0, cost 0.0 iteration 820
# m 0.0, b 0.0, cost 0.0 iteration 821
# m 0.0, b 0.0, cost 0.0 iteration 822
# m 0.0, b 0.0, cost 0.0 iteration 823
# m 0.0, b 0.0, cost 0.0 iteration 824
# m 0.0, b 0.0, cost 0.0 iteration 825
# m 0.0, b 0.0, cost 0.0 iteration 826
# m 0.0, b 0.0, cost 0.0 iteration 827
# m 0.0, b 0.0, cost 0.0 iteration 828
# m 0.0, b 0.0, cost 0.0 iteration 829
# m 0.0, b 0.0, cost 0.0 iteration 830
# m 0.0, b 0.0, cost 0.0 iteration 831
# m 0.0, b 0.0, cost 0.0 iteration 832
# m 0.0, b 0.0, cost 0.0 iteration 833
# m 0.0, b 0.0, cost 0.0 iteration 834
# m 0.0, b 0.0, cost 0.0 iteration 835
# m 0.0, b 0.0, cost 0.0 iteration 836
# m 0.0, b 0.0, cost 0.0 iteration 837
# m 0.0, b 0.0, cost 0.0 iteration 838
# m 0.0, b 0.0, cost 0.0 iteration 839
# m 0.0, b 0.0, cost 0.0 iteration 840
# m 0.0, b 0.0, cost 0.0 iteration 841
# m 0.0, b 0.0, cost 0.0 iteration 842
# m 0.0, b 0.0, cost 0.0 iteration 843
# m 0.0, b 0.0, cost 0.0 iteration 844
# m 0.0, b 0.0, cost 0.0 iteration 845
# m 0.0, b 0.0, cost 0.0 iteration 846
# m 0.0, b 0.0, cost 0.0 iteration 847
# m 0.0, b 0.0, cost 0.0 iteration 848
# m 0.0, b 0.0, cost 0.0 iteration 849
# m 0.0, b 0.0, cost 0.0 iteration 850
# m 0.0, b 0.0, cost 0.0 iteration 851
# m 0.0, b 0.0, cost 0.0 iteration 852
# m 0.0, b 0.0, cost 0.0 iteration 853
# m 0.0, b 0.0, cost 0.0 iteration 854
# m 0.0, b 0.0, cost 0.0 iteration 855
# m 0.0, b 0.0, cost 0.0 iteration 856
# m 0.0, b 0.0, cost 0.0 iteration 857
# m 0.0, b 0.0, cost 0.0 iteration 858
# m 0.0, b 0.0, cost 0.0 iteration 859
# m 0.0, b 0.0, cost 0.0 iteration 860
# m 0.0, b 0.0, cost 0.0 iteration 861
# m 0.0, b 0.0, cost 0.0 iteration 862
# m 0.0, b 0.0, cost 0.0 iteration 863
# m 0.0, b 0.0, cost 0.0 iteration 864
# m 0.0, b 0.0, cost 0.0 iteration 865
# m 0.0, b 0.0, cost 0.0 iteration 866
# m 0.0, b 0.0, cost 0.0 iteration 867
# m 0.0, b 0.0, cost 0.0 iteration 868
# m 0.0, b 0.0, cost 0.0 iteration 869
# m 0.0, b 0.0, cost 0.0 iteration 870
# m 0.0, b 0.0, cost 0.0 iteration 871
# m 0.0, b 0.0, cost 0.0 iteration 872
# m 0.0, b 0.0, cost 0.0 iteration 873
# m 0.0, b 0.0, cost 0.0 iteration 874
# m 0.0, b 0.0, cost 0.0 iteration 875
# m 0.0, b 0.0, cost 0.0 iteration 876
# m 0.0, b 0.0, cost 0.0 iteration 877
# m 0.0, b 0.0, cost 0.0 iteration 878
# m 0.0, b 0.0, cost 0.0 iteration 879
# m 0.0, b 0.0, cost 0.0 iteration 880
# m 0.0, b 0.0, cost 0.0 iteration 881
# m 0.0, b 0.0, cost 0.0 iteration 882
# m 0.0, b 0.0, cost 0.0 iteration 883
# m 0.0, b 0.0, cost 0.0 iteration 884
# m 0.0, b 0.0, cost 0.0 iteration 885
# m 0.0, b 0.0, cost 0.0 iteration 886
# m 0.0, b 0.0, cost 0.0 iteration 887
# m 0.0, b 0.0, cost 0.0 iteration 888
# m 0.0, b 0.0, cost 0.0 iteration 889
# m 0.0, b 0.0, cost 0.0 iteration 890
# m 0.0, b 0.0, cost 0.0 iteration 891
# m 0.0, b 0.0, cost 0.0 iteration 892
# m 0.0, b 0.0, cost 0.0 iteration 893
# m 0.0, b 0.0, cost 0.0 iteration 894
# m 0.0, b 0.0, cost 0.0 iteration 895
# m 0.0, b 0.0, cost 0.0 iteration 896
# m 0.0, b 0.0, cost 0.0 iteration 897
# m 0.0, b 0.0, cost 0.0 iteration 898
# m 0.0, b 0.0, cost 0.0 iteration 899
# m 0.0, b 0.0, cost 0.0 iteration 900
# m 0.0, b 0.0, cost 0.0 iteration 901
# m 0.0, b 0.0, cost 0.0 iteration 902
# m 0.0, b 0.0, cost 0.0 iteration 903
# m 0.0, b 0.0, cost 0.0 iteration 904
# m 0.0, b 0.0, cost 0.0 iteration 905
# m 0.0, b 0.0, cost 0.0 iteration 906
# m 0.0, b 0.0, cost 0.0 iteration 907
# m 0.0, b 0.0, cost 0.0 iteration 908
# m 0.0, b 0.0, cost 0.0 iteration 909
# m 0.0, b 0.0, cost 0.0 iteration 910
# m 0.0, b 0.0, cost 0.0 iteration 911
# m 0.0, b 0.0, cost 0.0 iteration 912
# m 0.0, b 0.0, cost 0.0 iteration 913
# m 0.0, b 0.0, cost 0.0 iteration 914
# m 0.0, b 0.0, cost 0.0 iteration 915
# m 0.0, b 0.0, cost 0.0 iteration 916
# m 0.0, b 0.0, cost 0.0 iteration 917
# m 0.0, b 0.0, cost 0.0 iteration 918
# m 0.0, b 0.0, cost 0.0 iteration 919
# m 0.0, b 0.0, cost 0.0 iteration 920
# m 0.0, b 0.0, cost 0.0 iteration 921
# m 0.0, b 0.0, cost 0.0 iteration 922
# m 0.0, b 0.0, cost 0.0 iteration 923
# m 0.0, b 0.0, cost 0.0 iteration 924
# m 0.0, b 0.0, cost 0.0 iteration 925
# m 0.0, b 0.0, cost 0.0 iteration 926
# m 0.0, b 0.0, cost 0.0 iteration 927
# m 0.0, b 0.0, cost 0.0 iteration 928
# m 0.0, b 0.0, cost 0.0 iteration 929
# m 0.0, b 0.0, cost 0.0 iteration 930
# m 0.0, b 0.0, cost 0.0 iteration 931
# m 0.0, b 0.0, cost 0.0 iteration 932
# m 0.0, b 0.0, cost 0.0 iteration 933
# m 0.0, b 0.0, cost 0.0 iteration 934
# m 0.0, b 0.0, cost 0.0 iteration 935
# m 0.0, b 0.0, cost 0.0 iteration 936
# m 0.0, b 0.0, cost 0.0 iteration 937
# m 0.0, b 0.0, cost 0.0 iteration 938
# m 0.0, b 0.0, cost 0.0 iteration 939
# m 0.0, b 0.0, cost 0.0 iteration 940
# m 0.0, b 0.0, cost 0.0 iteration 941
# m 0.0, b 0.0, cost 0.0 iteration 942
# m 0.0, b 0.0, cost 0.0 iteration 943
# m 0.0, b 0.0, cost 0.0 iteration 944
# m 0.0, b 0.0, cost 0.0 iteration 945
# m 0.0, b 0.0, cost 0.0 iteration 946
# m 0.0, b 0.0, cost 0.0 iteration 947
# m 0.0, b 0.0, cost 0.0 iteration 948
# m 0.0, b 0.0, cost 0.0 iteration 949
# m 0.0, b 0.0, cost 0.0 iteration 950
# m 0.0, b 0.0, cost 0.0 iteration 951
# m 0.0, b 0.0, cost 0.0 iteration 952
# m 0.0, b 0.0, cost 0.0 iteration 953
# m 0.0, b 0.0, cost 0.0 iteration 954
# m 0.0, b 0.0, cost 0.0 iteration 955
# m 0.0, b 0.0, cost 0.0 iteration 956
# m 0.0, b 0.0, cost 0.0 iteration 957
# m 0.0, b 0.0, cost 0.0 iteration 958
# m 0.0, b 0.0, cost 0.0 iteration 959
# m 0.0, b 0.0, cost 0.0 iteration 960
# m 0.0, b 0.0, cost 0.0 iteration 961
# m 0.0, b 0.0, cost 0.0 iteration 962
# m 0.0, b 0.0, cost 0.0 iteration 963
# m 0.0, b 0.0, cost 0.0 iteration 964
# m 0.0, b 0.0, cost 0.0 iteration 965
# m 0.0, b 0.0, cost 0.0 iteration 966
# m 0.0, b 0.0, cost 0.0 iteration 967
# m 0.0, b 0.0, cost 0.0 iteration 968
# m 0.0, b 0.0, cost 0.0 iteration 969
# m 0.0, b 0.0, cost 0.0 iteration 970
# m 0.0, b 0.0, cost 0.0 iteration 971
# m 0.0, b 0.0, cost 0.0 iteration 972
# m 0.0, b 0.0, cost 0.0 iteration 973
# m 0.0, b 0.0, cost 0.0 iteration 974
# m 0.0, b 0.0, cost 0.0 iteration 975
# m 0.0, b 0.0, cost 0.0 iteration 976
# m 0.0, b 0.0, cost 0.0 iteration 977
# m 0.0, b 0.0, cost 0.0 iteration 978
# m 0.0, b 0.0, cost 0.0 iteration 979
# m 0.0, b 0.0, cost 0.0 iteration 980
# m 0.0, b 0.0, cost 0.0 iteration 981
# m 0.0, b 0.0, cost 0.0 iteration 982
# m 0.0, b 0.0, cost 0.0 iteration 983
# m 0.0, b 0.0, cost 0.0 iteration 984
# m 0.0, b 0.0, cost 0.0 iteration 985
# m 0.0, b 0.0, cost 0.0 iteration 986
# m 0.0, b 0.0, cost 0.0 iteration 987
# m 0.0, b 0.0, cost 0.0 iteration 988
# m 0.0, b 0.0, cost 0.0 iteration 989
# m 0.0, b 0.0, cost 0.0 iteration 990
# m 0.0, b 0.0, cost 0.0 iteration 991
# m 0.0, b 0.0, cost 0.0 iteration 992
# m 0.0, b 0.0, cost 0.0 iteration 993
# m 0.0, b 0.0, cost 0.0 iteration 994
# m 0.0, b 0.0, cost 0.0 iteration 995
# m 0.0, b 0.0, cost 0.0 iteration 996
# m 0.0, b 0.0, cost 0.0 iteration 997
# m 0.0, b 0.0, cost 0.0 iteration 998
# m 0.0, b 0.0, cost 0.0 iteration 999
